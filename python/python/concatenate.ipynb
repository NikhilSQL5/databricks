# %% [markdown]
# ### merging the two strings

# %%
"hello" + " " + "world"

# %%
x = "hello" + " " + "world"
print(x)

# %% [markdown]
# ### data type conversion
# - str to int
# - int to str

# %%
a = 10 + int("10")

b = str(10) + "10"

print(a)
print(b)
