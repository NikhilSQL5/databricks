# %% [markdown]
# #### if statement

# %%
is_logged_in = True
if is_logged_in:
  print("Welcome back!")

# %% [markdown]
# #### if else statement

# %%
a = 10
b = 20
if(a>b):
    print("a is greater than b")
else: 
    print("b is greater than a")

# %% [markdown]
# #### if elif else

# %%
a = 5
b = 5

if(a>b):
    print("a is greter than b")
elif(b>a):
    print("b is greater than a")
else:
    print("a and b is equal")
