# %% [markdown]
# #### input use to get the input from the user
#
# by default it convert it into the string

# %%
num1 = int(input("enter the 1st number to add"))
num2 = int(input("enter the 2nd number to add"))
num3 = num1 + num2
print(f"the addition of the 1st number and the 2nd number is {num3}")

# %%
marks = int(input("enter the marks"))

if (marks>50):
    print("pass")
else:
    print("fail")
