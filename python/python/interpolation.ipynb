# %% [markdown]
# ### interpolation
#
# it is the technique to replace the value of the variable in placeholder

# %%
x = 5
print(x)

# %%
print("the vlaue of the x is: " + str(x))

# %%
y = "hello"

print("the value of the x is: " + str(x) + " and the value of the variable y is " + y)

# %% [markdown]
# #### string interpolation

# %%
print("the value of the x is: %s" %(x))

# %% [markdown]
# string interpolation passing the multiple values

# %%
print("the value of the x is %s and the value is b is %s " %(x,y))

# %% [markdown]
# using the .formate()

# %%
print("the value of the x is {}".format(x))

# %% [markdown]
# using the key and value

# %%
print("the value of the x is {a1}".format(a1=x))

# %% [markdown]
# using the f keyword

# %%
print(f"the value of the x is {x}")

# %% [markdown]
# control the decimal number

# %%
t = 55.55555555
print (t)
print("the value of the t is %.2f"%(t))
