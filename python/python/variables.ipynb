# %% [markdown]
# ### variable
#
# - variable store the value like stringor number etc
# - variable only store one value at the time
# - it hold the latest value only
# - variable created at the memory

# %%
y = "hello"

print (y)

# %% [markdown]
# ### type
# to check the data type of the variable

# %%
type(y)

# %% [markdown]
# ### assign value
#
# assign same value to the multiple variable

# %%
a = b = c = 5

# %%
print (a,b,c)

# %% [markdown]
# ### swap the value

# %%
q = 5
w = 10
print (q,w)

q,w =w,q
print (q,w)

# %% [markdown]
# assign multiple variable and value in single line

# %%
q,w,e,r = 1,2,3,4
print(q,w,e,r)
